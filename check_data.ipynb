# %%
import json
import pprint 

pp = pprint.PrettyPrinter(indent=4, width=200)

# %%
DATA_PATH = "../bioasq-biobert/data/BioASQ-6b/test/Full-Abstract/BioASQ-test-factoid-6b-3.json"

with open(DATA_PATH, "r") as f:
    data = json.load(f)

# %%
# data = {"version", "data"}
# data['data']: List : Dict {'title', 'paragraphs'}
# data['data']['paragraphs']: List: Dict {'context', 'qas'}
# data['data']['paragraphs']['qas']: List: Dict {'question', 'id'}
# sample = data['data'][0]
# print(sample['title'])

# paragraphs = sample['paragraphs'][0]
# print(paragraphs)

# {
#     "version": "",
#     "data": [
#         {
#             "title":"",
#             "paragraphs": [
#                 {
#                     "context": ""
#                     "qas": [
#                         {
#                             'question': "",
#                             'id': "",
#                             'answer': "",
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }

# %%
synthetic = {
    'version': 'synthetic',
    'data': []
            }

data_item = {
    'title': 'synthetic',
    'paragraphs': []
}

paragraph_item = {
    'context': '',
    'qas': []
}

"""
qas_item = {'question': '', 'id': ''}
"""
# Out:
# "\nqas_item = {'question': '', 'id': ''}\n"

# %%
context = "First, symptom screening depends on the natural history of an infection: individuals are increasingly likely to show detectable symptoms with increasing time since exposure. A fundamental shortcoming of screening is the difficulty of detecting infected individuals during their incubation period, or early after the onset of symptoms, at which point they still feel healthy enough to undertake normal activities or travel. This difficulty is amplified when the incubation period is longer; infected individuals have a longer window in which they may mix socially or travel with low probability of detection. Second, screening depends on whether exposure risk factors exist that would facilitate specific and reasonably sensitive case detection by questionnaire. For COVID-19, there is so far limited evidence for specific risk factors; we therefore assumed that at most 40% of travellers would be aware of a potential exposure. It is plausible that many individuals aware of a potential exposure would voluntarily avoid travel and practice social distancing--if so, the population of infected travellers will be skewed toward those unaware they have been exposed."

paragraph_item = {
    'context': context,
    'qas': []
}

qas_item = {
    'question': 'What do we know about COVID-19 risk factors?', 
    'id': 0,
    'answer': 'limited evidence for specific risk factors',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What is the fundamental shortcoming of screening?', 
    'id': 1,
    'answer': 'the difficulty of detecting infected individuals during their incubation period, or early after the onset of symptoms',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'Which kind of travellers are more likely to be infected?', 
    'id': 2,
    'answer': 'those unaware they have been exposed',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'Symptom screening depends on what?', 
    'id': 3,
    'answer': 'the natural history of an infection and whether exposure risk factors exist',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What will happen with increasing time since exposure?', 
    'id': 4,
    'answer': 'individuals are increasingly likely to show detectable symptoms',
}

paragraph_item['qas'].append(qas_item)

data_item = {
    'title': 'synthetic',
    'paragraphs': [paragraph_item],
}

synthetic['data'].append(data_item)

# %%
context = 'Of all 91 patients, 88 (96.70%) were laboratory-confirmed COVID-19 with throat swab samples that tested positive for SARS-Cov-2 while 3 (3.30%) were clinical-diagnosed COVID-19 cases. The median age of the patients was 50 (36.5-57) years, and female accounted for 59.34%. In this sample 40 (43.96%) patients had contracted the diseases from local cases, 31 (34.07%) patients had been to Wuhan/Hubei, 8 (8.79%) cases had contacted with people from Wuhan, 11 (12.09%) cases were confirmed aircraft transmission. In particular within the city of Ningbo, 60.52% cases can be traced back to an event held in a temple. The most common symptoms were fever (71.43%), cough (60.44%) and fatigue (43.96%). The median of incubation period was 6 (IQR, 3-8) days and the median time from first visit to a doctor to confirmed diagnosis was 1 (1-2) days. According to the Chest computed tomography scans, 67.03% cases had bilateral pneumonia.'

paragraph_item = {
    'context': context,
    'qas': []
}

qas_item = {
    'question': 'What is the median age of the patients?', 
    'id': 5,
    'answer': '50',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What is the median of incubation period?', 
    'id': 6,
    'answer': '6 days',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What are the most common symptoms?', 
    'id': 7,
    'answer': 'fever (71.43%), cough (60.44%) and fatigue (43.96%)',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'How many percent of them got confirmed by clinical-diagnose?', 
    'id': 8,
    'answer': '3.30%',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'How many patient was sampled in total?', 
    'id': 9,
    'answer': '91',
}

paragraph_item['qas'].append(qas_item)

data_item = {
    'title': 'synthetic',
    'paragraphs': [paragraph_item],
}

synthetic['data'].append(data_item)

# %%
context = 'The confirmation rate of Wuhan is 0.0643, significantly lower than 0.1914 of Hubei (excluding Wuhan) and 0.2189 of China (excluding Hubei), but increases to 0.3229 after Feb 12th when clinical diagnosis was adopted. The un-quarantined infected individuals in Wuhan on February 12, 2020 is as high as 3,509 and decreases to 334 on February 21th, 2020. After fitting the model with recent data, we predict that the end times of COVID-19 of Wuhan and Hubei are around late-March, of China (excluding Hubei) around mid-March, and of the four tier-one cities before March 2020. A total of 80,511 individuals of the whole country are infected, among which 49,510 are from Wuhan, 17,679 from Hubei(excluding Wuhan), and the rest 13,322 from other regions of China (excluding Hubei). We suggest the rigorous quarantine and control measures should be kept before March in Beijing, Shanghai, Guangzhou and Shenzhen, and before late-March in Hubei. The model can also be useful to predict the trend of epidemic and provide quantitative guide for other counties in a high risk of outbreak, such as South Korea, Japan and Iran.'

paragraph_item = {
    'context': context,
    'qas': []
}

qas_item = {
    'question': 'How many people in total got infected in China?', 
    'id': 10,
    'answer': '80,511',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'Which cities are suggested to conduct strict quarantine and control measures?', 
    'id': 11,
    'answer': 'Beijing, Shanghai, Guangzhou and Shenzhen, and before late-March in Hubei',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What is suggested to do for corona virus?', 
    'id': 12,
    'answer': 'rigorous quarantine and control measures',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What are the other counties in a high risk of outbreak?', 
    'id': 13,
    'answer': 'South Korea, Japan and Iran',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What is the confirmation rate of Wuhan after Feb 12th?', 
    'id': 14,
    'answer': '0.3229',
}

paragraph_item['qas'].append(qas_item)

data_item = {
    'title': 'synthetic',
    'paragraphs': [paragraph_item],
}

synthetic['data'].append(data_item)

# %%
context = 'In Wuhan, where the largest number of infected people live, residents were required to measure and report ther temperature daily to confirm their onset, and those with mild and asymptomatic infections were also quarantined in “Fang Cang” hospitals, which are public spaces such as stadiums and conference centres that have been repurposed for medical care. Third, inner-city travel and contact restrictions were implemented to reduce the risk of community transmission. This involved limiting individual social contact, using personal hygiene and protective measures when people needed to move in public, and increasing the physical distance between those who have COVID-19 and those who do not. As part of these social distancing policies, Chinese government encouraged people to stay at home as much as possible, cancelled or postponed large public events and mass gatherings, and closed libraries, museums, and workplaces. Additionally, to fully cover the suspected incubation period of COVID-19 spread before Wuhan’s lockdown, the CNY and school holidays were also extended, with the holiday end date changed from January 30 to March 10 for Hubei province, and Feb 9 for many other provinces.'

paragraph_item = {
    'context': context,
    'qas': []
}

qas_item = {
    'question': 'What measure was conducted to reduce the risk of community transmission?', 
    'id': 15,
    'answer': 'inner-city travel and contact restrictions',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'The CNY and school holidays in provinces other than Hubei were entended to when?', 
    'id': 16,
    'answer': 'Feb 9',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What do Wuhan residents do every day to confirm their onset?', 
    'id': 17,
    'answer': 'measure and report ther temperature daily',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What have been repurposed for medical care?', 
    'id': 18,
    'answer': 'stadiums and conference centres',
}

paragraph_item['qas'].append(qas_item)

qas_item = {
    'question': 'What do inner-city travel and contact restrictions involve?', 
    'id': 19,
    'answer': 'limiting individual social contact, using personal hygiene and protective measures when people needed to move in public, and increasing the physical distance between those who have COVID-19 and those who do not',
}

paragraph_item['qas'].append(qas_item)

data_item = {
    'title': 'synthetic',
    'paragraphs': [paragraph_item],
}

synthetic['data'].append(data_item)

# %%
pp.pprint(synthetic)
# Out:
# {   'data': [   {   'paragraphs': [   {   'context': 'First, symptom screening depends on the natural history of an infection: individuals are increasingly likely to show detectable symptoms with '
#                                                      'increasing time since exposure. A fundamental shortcoming of screening is the difficulty of detecting infected individuals during their '
#                                                      'incubation period, or early after the onset of symptoms, at which point they still feel healthy enough to undertake normal activities or travel. '
#                                                      'This difficulty is amplified when the incubation period is longer; infected individuals have a longer window in which they may mix socially or '
#                                                      'travel with low probability of detection. Second, screening depends on whether exposure risk factors exist that would facilitate specific and '
# ...

# %%
with open("test/synthetic_test.json", "w") as f:
    json.dump(synthetic, f)

# %%
_id = []
_label = []
synthetic_data = synthetic['data']
for item in synthetic_data:
    paragraphs = item['paragraphs']
    for paragraph in paragraphs:
        qas = paragraph['qas']
        for q in qas:
            _id.append(q['id'])
            _label.append(q['answer'])

# %%
golden = {}
for num, i in enumerate(_id):
    golden[i] = _label[num]

pp.pprint(golden)
# Out:
# {   0: 'limited evidence for specific risk factors',
#     1: 'the difficulty of detecting infected individuals during their incubation period, or early after the onset of symptoms',
#     2: 'those unaware they have been exposed',
#     3: 'the natural history of an infection and whether exposure risk factors exist',
#     4: 'individuals are increasingly likely to show detectable symptoms',
#     5: '50',
#     6: '6 days',
#     7: 'fever (71.43%), cough (60.44%) and fatigue (43.96%)',
#     8: '3.30%',
#     9: '91',
#     10: '80,511',
#     11: 'Beijing, Shanghai, Guangzhou and Shenzhen, and before late-March in Hubei',
#     12: 'rigorous quarantine and control measures',
#     13: 'South Korea, Japan and Iran',
#     14: '0.3229',
#     15: 'inner-city travel and contact restrictions',
#     16: 'Feb 9',
#     17: 'measure and report ther temperature daily',
#     18: 'stadiums and conference centres',
# ...

# %%
with open("test/synthetic_golden.json", "w") as f:
    json.dump(golden, f)
